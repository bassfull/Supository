# %%
nome_prof = input('Qual o nome do seu professor? ')
print('uiui gostei de', nome_prof)


barbudo = input('Ele é um barbudo gostoso s/n?')
if barbudo == 's':
  print('Me passa o zap dele ai ')
else:
  print('ok')
# Out:
# Qual o nome do seu professor? zarck
# uiui gostei de zarck
# Ele é um barbudo gostoso s/n?n
# ok
